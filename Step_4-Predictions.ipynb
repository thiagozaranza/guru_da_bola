# %% [markdown]
# # Campeonato Brasileiro - Série A

# %% [markdown]
# ## Radom Forest Classifier

# %% [markdown]
# ### 1. Import packages

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,precision_score, recall_score
from sklearn.metrics import f1_score

# %%
from sklearn import datasets

# %% [markdown]
# ### 2. Reading data

# %%
jogos = pd.read_csv("data/matches-results-positions.9.csv",sep=",")

# %%
del jogos["Unnamed: 0"]

# %%
#jogos.query('ano > 2012', inplace=True)

# %%
jogos.head(3)
# Out:
#    Unnamed: 0.1    campeonato   ano  rodada   data    mandante    visitante  \
# 0             0  brasileiro-a  2018       9  04-06      Paraná   Fluminense
# 1             1  brasileiro-a  2018       9  03-06       Ceará     Cruzeiro
# 2             2  brasileiro-a  2018       9  03-06  América-MG  Atlético-PR
#
#    gols_mandante  gols_visitante  resultado  posicao_m  posicao_v  \
# 0              2               1   MANDANTE       19.0        8.0
# 1              0               1  VISITANTE       20.0        2.0
# 2              3               1   MANDANTE       10.0       16.0
#
#    aproveitamento_5r_v  aproveitamento_5r_m  aproveitamento_10r_v  \
# 0                 0.67                 0.20                  0.67
# 1                 0.80                 0.13                  0.62
# 2                 0.27                 0.27                  0.29
#
#    aproveitamento_10r_m
# 0                  0.14
# 1                  0.14
# 2                  0.33

# %%
jogos.keys()
# Out:
# Index(['Unnamed: 0.1', 'campeonato', 'ano', 'rodada', 'data', 'mandante',
#        'visitante', 'gols_mandante', 'gols_visitante', 'resultado',
#        'posicao_m', 'posicao_v', 'aproveitamento_5r_v', 'aproveitamento_5r_m',
#        'aproveitamento_10r_v', 'aproveitamento_10r_m'],
#       dtype='object')

# %%
times = np.concatenate((jogos["visitante"].unique(), jogos["mandante"].unique()), axis=0)

# %%
times_dict = dict(zip(times, range(1, len(times))))

# %%
times_dict
# Out:
# {'América-MG': 44,
#  'América-RN': 78,
#  'Atlético-GO': 62,
#  'Atlético-MG': 50,
#  'Atlético-PR': 52,
#  'Avaí': 63,
#  'Bahia': 45,
#  'Barueri': 73,
#  'Botafogo': 61,
#  'Brasiliense': 40,
#  'Ceará': 43,
#  'Chapecoense': 56,
#  'Corinthians': 53,
#  'Coritiba': 64,
#  'Criciúma': 70,
#  'Cruzeiro': 54,
#  'Figueirense': 66,
#  'Flamengo': 46,
#  'Fluminense': 60,
#  'Fortaleza': 79,
#  'Goias': 68,
#  'Grêmio': 55,
#  'Guarani': 74,
#  'Internacional': 51,
#  'Ipatinga': 76,
#  'Joinville': 69,
#  'Juventude': 77,
#  'Náutico': 72,
#  'Palmeiras': 48,
#  'Paraná': 42,
#  'Paysandu': 81,
#  'Ponte Preta': 65,
#  'Portuguesa': 71,
#  'Santa Cruz': 67,
#  'Santo Andre': 75,
#  'Santos': 47,
#  'Sao Caetano': 80,
#  'Sport Recife': 58,
#  'São Paulo': 57,
#  'Vasco': 49,
#  'Vitória': 59}

# %%
jogos = jogos.applymap(lambda s: times_dict.get(s) if s in times_dict else s)

# %% [markdown]
# ### 3. Define target and data subset

# %%
jogos_X_df = jogos.copy()

# %%
del jogos_X_df["resultado"]

# %%
del jogos_X_df["campeonato"]

# %%
del jogos_X_df["data"]

# %%
del jogos_X_df["gols_mandante"]

# %%
del jogos_X_df["gols_visitante"]

# %%
del jogos_X_df["aproveitamento_5r_v"]

# %%
del jogos_X_df["aproveitamento_5r_m"]

# %%
del jogos_X_df["Unnamed: 0.1"]

# %%
jogos_X_df.head()
# Out:
#     ano  rodada  mandante  visitante  posicao_m  posicao_v  \
# 0  2018       9        42         60       19.0        8.0
# 1  2018       9        43         54       20.0        2.0
# 2  2018       9        44         52       10.0       16.0
# 3  2018       9        45         55       18.0        3.0
# 4  2018       9        46         53        1.0        7.0
#
#    aproveitamento_10r_v  aproveitamento_10r_m
# 0                  0.67                  0.14
# 1                  0.62                  0.14
# 2                  0.29                  0.33
# 3                  0.48                  0.38
# 4                  0.52                  0.76

# %%
jogos_X_df.keys()
# Out:
# Index(['ano', 'rodada', 'mandante', 'visitante', 'posicao_m', 'posicao_v',
#        'aproveitamento_10r_v', 'aproveitamento_10r_m'],
#       dtype='object')

# %%
y = jogos["resultado"].values

# %%
X = jogos_X_df.values

# %% [markdown]
# ### 4. Train and Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
                                        X,
                                        y, 
                                        test_size=0.2, 
                                        random_state=1)

# %% [markdown]
# ### 4.1 Grid Search

# %%
from sklearn.grid_search import GridSearchCV

# %%
from sklearn.datasets import make_classification

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_jobs=-1,max_features= 'sqrt' ,n_estimators=50, oob_score = True)

# %%
param_grid = {     
    'n_estimators': [800],
    'min_samples_leaf': [10],
    'max_features': ['log2'],
    'n_jobs': [-1],
    'min_samples_split': [3],
    'warm_start': [False],
    'oob_score':  [False], 
    'bootstrap': [True],
    'criterion': ['entropy'],
    'class_weight': ['balanced', 'balanced_subsample', None]
}

# %%
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)

# %%
CV_rfc.fit(X, y)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
#             oob_score=True, random_state=None, verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [800], 'min_samples_leaf': [10], 'max_features': ['log2'], 'n_jobs': [-1], 'min_samples_split': [3], 'warm_start': [False], 'oob_score': [False], 'bootstrap': [True], 'criterion': ['entropy'], 'class_weight': ['balanced', 'balanced_subsample', None]},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=0)

# %%
print (CV_rfc.best_params_)
# Out:
# {'bootstrap': True, 'class_weight': None, 'criterion': 'entropy', 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 3, 'n_estimators': 800, 'n_jobs': -1, 'oob_score': False, 'warm_start': False}

# %% [markdown]
# ### 5. Apply Random Forest Classifier

# %%
rf_model = RandomForestClassifier(random_state=1, criterion='entropy', max_features='log2', n_estimators=800, min_samples_leaf=10)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='log2', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=10, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=800, n_jobs=1,
#             oob_score=False, random_state=1, verbose=0, warm_start=False)

# %% [markdown]
# ### 6. Model Cross-Validation

# %%
cv_scores_rf = cross_val_score(rf_model, X_train, y_train, 
                               cv=5,scoring="accuracy")
cv_scores_rf
# Out:
# array([ 0.59798995,  0.5915493 ,  0.59255533,  0.59959759,  0.59054326])

# %%
cv_scores_rf_mean =  np.mean(cv_scores_rf)
cv_scores_rf_mean
# Out:
# 0.59444708451715322

# %% [markdown]
# ### Apply AdaBoostClassifier

# %%
abc_model = AdaBoostClassifier(random_state=1, n_estimators=50, learning_rate=1., algorithm="SAMME.R")

# %%
abc_model.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=1)

# %%
cv_scores_abc = cross_val_score(abc_model, X_train, y_train, 
                               cv=5,scoring="accuracy")
cv_scores_abc
# Out:
# array([ 0.58291457,  0.58249497,  0.58148893,  0.57545272,  0.58853119])

# %%
cv_scores_abc_mean =  np.mean(cv_scores_abc)
cv_scores_abc_mean
# Out:
# 0.58217647594107358

# %% [markdown]
# ### 7. Model Test

# %%
y_test_pred = rf_model.predict(X_test)

# %%
y_test.shape
# Out:
# (1243,)

# %%
# Results
pd.crosstab(y_test, y_test_pred,
            rownames=['Actual'], 
            colnames=['Predicted'])
# Out:
# Predicted  EMPATE  MANDANTE  VISITANTE
# Actual
# EMPATE         39       241         61
# MANDANTE       21       544         44
# VISITANTE      21       141        131

# %%
confusion_matrix(y_test, y_test_pred)
# Out:
# array([[ 39, 241,  61],
#        [ 21, 544,  44],
#        [ 21, 141, 131]])

# %%
accuracy_score_test = accuracy_score(y_test, y_test_pred)
accuracy_score_test
# Out:
# 0.57441673370876911

# %%
#precision_score_forest = precision_score(y_test, y_test_pred)
#precision_score_forest

# %%
#recall_score_forest = recall_score(y_test, y_test_pred)
#recall_score_forest

# %%
#f1_score_forest = f1_score(y_test, y_test_pred)
#f1_score_forest

# %% [markdown]
# ### 8. Comparison accuracy: Validation vs Test

# %%
comparison = {"Validation": [cv_scores_rf_mean],
             "Test": [accuracy_score_test]}
pd.DataFrame(comparison, index = ["Accuracy"])
# Out:
#               Test  Validation
# Accuracy  0.574417    0.594447

# %% [markdown]
# ### 9. Feature Importance

# %%
rf_model.feature_importances_
# Out:
# array([ 0.06803089,  0.13292503,  0.08262914,  0.08378799,  0.21138386,
#         0.20205659,  0.1039028 ,  0.11528371])

# %%
# View a list of the features and their importance scores
imp_list = list(zip(jogos_X_df.keys(), 
                    rf_model.feature_importances_))
imp_df = pd.DataFrame(imp_list, columns = ["Features", "Importance"])
imp_df.sort_values(by = "Importance", ascending = False)
# Out:
#                Features  Importance
# 4             posicao_m    0.211384
# 5             posicao_v    0.202057
# 1                rodada    0.132925
# 7  aproveitamento_10r_m    0.115284
# 6  aproveitamento_10r_v    0.103903
# 3             visitante    0.083788
# 2              mandante    0.082629
# 0                   ano    0.068031

# %% [markdown]
# ### 10. Predict

# %%
rodada = pd.read_csv("data/turn.10.csv",sep=",")

# %%
rodada
# Out:
#        mandante      visitante  placar
# 0     São Paulo  Internacional     NaN
# 1      Botafogo          Ceará     NaN
# 2       Vitória    Chapecoense     NaN
# 3   Corinthians         Santos     NaN
# 4  Sport Recife    Atlético-PR     NaN
# 5      Cruzeiro          Vasco     NaN
# 6        Grêmio      Palmeiras     NaN
# 7    Fluminense       Flamengo     NaN
# 8        Paraná          Bahia     NaN
# 9    América-MG    Atlético-MG     NaN

# %%
rodada_DF = rodada.copy()

# %%
rodada_DF = rodada_DF.applymap(lambda s: times_dict.get(s) if s in times_dict else s)

# %%
rodada_DF
# Out:
#    mandante  visitante  placar
# 0        57         51     NaN
# 1        61         43     NaN
# 2        59         56     NaN
# 3        53         47     NaN
# 4        58         52     NaN
# 5        54         49     NaN
# 6        55         48     NaN
# 7        60         46     NaN
# 8        42         45     NaN
# 9        44         50     NaN

# %%
jogos.head(3)
# Out:
#    Unnamed: 0.1    campeonato   ano  rodada   data  mandante  visitante  \
# 0             0  brasileiro-a  2018       9  04-06        42         60
# 1             1  brasileiro-a  2018       9  03-06        43         54
# 2             2  brasileiro-a  2018       9  03-06        44         52
#
#    gols_mandante  gols_visitante  resultado  posicao_m  posicao_v  \
# 0              2               1   MANDANTE       19.0        8.0
# 1              0               1  VISITANTE       20.0        2.0
# 2              3               1   MANDANTE       10.0       16.0
#
#    aproveitamento_5r_v  aproveitamento_5r_m  aproveitamento_10r_v  \
# 0                 0.67                 0.20                  0.67
# 1                 0.80                 0.13                  0.62
# 2                 0.27                 0.27                  0.29
#
#    aproveitamento_10r_m
# 0                  0.14
# 1                  0.14
# 2                  0.33

# %%
jogos.query("visitante == 54 and rodada == 30 and ano == 2017")
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, campeonato, ano, rodada, data, mandante, visitante, gols_mandante, gols_visitante, resultado, posicao_m, posicao_v, aproveitamento_5r_v, aproveitamento_5r_m, aproveitamento_10r_v, aproveitamento_10r_m]
# Index: []

# %%
ano = jogos["ano"].max()

# %%
rod = jogos[jogos["ano"] == ano]["rodada"].max()

# %%
rodada_DF["ano"] = ano

# %%
rodada_DF["rodada"] = rod + 1

# %%
def getPosicao(jogos, ano, rodada, time):    

    ultimo_jogo = jogos.query("ano == " + str(ano) + " and rodada == " + str(rodada) + " and mandante == " + str(time))
    if not ultimo_jogo.empty:
        return ultimo_jogo["posicao_m"].values[0]
    
    ultimo_jogo = jogos.query("ano == " + str(ano) + " and rodada == " + str(rodada) + " and visitante == " + str(time))        
    return ultimo_jogo["posicao_v"].values[0]

# %%
def getAproveitamento(jogos, ano, rodada, time):    

    ultimo_jogo = jogos.query("ano == " + str(ano) + " and rodada == " + str(rodada) + " and mandante == " + str(time))
    if not ultimo_jogo.empty:
        return ultimo_jogo["aproveitamento_10r_m"].values[0]
    
    ultimo_jogo = jogos.query("ano == " + str(ano) + " and rodada == " + str(rodada) + " and visitante == " + str(time))        
    return ultimo_jogo["aproveitamento_10r_v"].values[0]

# %%
jogos
# Out:
#       Unnamed: 0.1    campeonato   ano  rodada   data  mandante  visitante  \
# 0                0  brasileiro-a  2018       9  04-06        42         60
# 1                1  brasileiro-a  2018       9  03-06        43         54
# 2                2  brasileiro-a  2018       9  03-06        44         52
# 3                3  brasileiro-a  2018       9  03-06        45         55
# 4                4  brasileiro-a  2018       9  03-06        46         53
# 5                5  brasileiro-a  2018       9  03-06        47         59
# 6                6  brasileiro-a  2018       9  02-06        48         57
# 7                7  brasileiro-a  2018       9  02-06        49         61
# 8                8  brasileiro-a  2018       9  02-06        50         56
# 9                9  brasileiro-a  2018       9  02-06        51         58
# 10              10  brasileiro-a  2018       8  31-05        52         47
# 11              11  brasileiro-a  2018       8  31-05        53         44
# 12              12  brasileiro-a  2018       8  31-05        46         45
# 13              13  brasileiro-a  2018       8  30-05        54         48
# 14              14  brasileiro-a  2018       8  30-05        55         60
# 15              15  brasileiro-a  2018       8  30-05        56         43
# 16              16  brasileiro-a  2018       8  30-05        57         61
# 17              17  brasileiro-a  2018       8  30-05        58         50
# 18              18  brasileiro-a  2018       8  30-05        49         42
# 19              19  brasileiro-a  2018       8  30-05        59         51
# 20              20  brasileiro-a  2018       7  26-05        50         46
# 21              21  brasileiro-a  2018       7  26-05        48         58
# 22              22  brasileiro-a  2018       7  26-05        60         56
# 23              23  brasileiro-a  2018       7  27-05        42         52
# 24              24  brasileiro-a  2018       7  27-05        45         49
# 25              25  brasileiro-a  2018       7  27-05        61         59
# 26              26  brasileiro-a  2018       7  27-05        51         53
# 27              27  brasileiro-a  2018       7  27-05        47         54
# 28              28  brasileiro-a  2018       7  27-05        44         57
# 29              29  brasileiro-a  2018       7  27-05        43         55
# ...            ...           ...   ...     ...    ...       ...        ...
# 6184          6184  brasileiro-a  2003       3  13-04        59         49
# 6185          6185  brasileiro-a  2003       3  12-04        53         81
# 6186          6186  brasileiro-a  2003       3  12-04        52         50
# 6187          6187  brasileiro-a  2003       3  12-04        51         45
# 6188          6188  brasileiro-a  2003       3  12-04        47         66
# 6189          6189  brasileiro-a  2003       4  09-04        81         47
# 6190          6190  brasileiro-a  2003       2  06-04        49         68
# 6191          6191  brasileiro-a  2003       2  06-04        45         46
# 6192          6192  brasileiro-a  2003       2  06-04        66         53
# 6193          6193  brasileiro-a  2003       2  06-04        42         52
# 6194          6194  brasileiro-a  2003       2  06-04        81         59
# 6195          6195  brasileiro-a  2003       2  06-04        65         77
# 6196          6196  brasileiro-a  2003       2  06-04        80         70
# 6197          6197  brasileiro-a  2003       2  06-04        57         54
# 6198          6198  brasileiro-a  2003       2  05-04        55         74
# 6199          6199  brasileiro-a  2003       2  05-04        50         47
# 6200          6200  brasileiro-a  2003       2  05-04        64         51
# 6201          6201  brasileiro-a  2003       2  05-04        60         79
# 6202          6202  brasileiro-a  2003       1  30-03        53         50
# 6203          6203  brasileiro-a  2003       1  30-03        47         42
# 6204          6204  brasileiro-a  2003       1  30-03        70         60
# 6205          6205  brasileiro-a  2003       1  30-03        54         80
# 6206          6206  brasileiro-a  2003       1  30-03        46         64
# 6207          6207  brasileiro-a  2003       1  30-03        79         45
# 6208          6208  brasileiro-a  2003       1  30-03        68         81
# 6209          6209  brasileiro-a  2003       1  30-03        51         65
# 6210          6210  brasileiro-a  2003       1  30-03        77         57
# 6211          6211  brasileiro-a  2003       1  30-03        59         66
# 6212          6212  brasileiro-a  2003       1  29-03        52         55
# 6213          6213  brasileiro-a  2003       1  29-03        74         49
#
#       gols_mandante  gols_visitante  resultado  posicao_m  posicao_v  \
# 0                 2               1   MANDANTE       19.0        8.0
# 1                 0               1  VISITANTE       20.0        2.0
# 2                 3               1   MANDANTE       10.0       16.0
# 3                 0               2  VISITANTE       18.0        3.0
# 4                 1               0   MANDANTE        1.0        7.0
# 5                 5               2   MANDANTE       15.0       17.0
# 6                 3               1   MANDANTE        6.0        4.0
# 7                 1               2  VISITANTE       13.0       12.0
# 8                 3               3     EMPATE        9.0       14.0
# 9                 0               0     EMPATE       11.0        5.0
# 10                2               0   MANDANTE       13.0       18.0
# 11                1               0   MANDANTE        3.0       12.0
# 12                2               0   MANDANTE        1.0       17.0
# 13                1               0   MANDANTE        6.0        9.0
# 14                0               0     EMPATE        8.0        4.0
# 15                2               0   MANDANTE       15.0       19.0
# 16                3               2   MANDANTE        2.0       14.0
# 17                3               2   MANDANTE        5.0        7.0
# 18                1               0   MANDANTE       10.0       20.0
# 19                2               3  VISITANTE       16.0       11.0
# 20                0               1  VISITANTE        3.0        1.0
# 21                2               3  VISITANTE        7.0        8.0
# 22                3               1   MANDANTE        2.0       18.0
# 23                0               0     EMPATE       20.0       17.0
# 24                3               0   MANDANTE       15.0       12.0
# 25                1               1     EMPATE       11.0       14.0
# 26                2               1   MANDANTE       13.0        6.0
# 27                0               1  VISITANTE       16.0        9.0
# 28                1               3  VISITANTE       10.0        4.0
# 29                0               1  VISITANTE       19.0        5.0
# ...             ...             ...        ...        ...        ...
# 6184              2               1   MANDANTE        5.0       15.0
# 6185              6               1   MANDANTE        9.0       24.0
# 6186              1               2  VISITANTE       16.0        3.0
# 6187              2               0   MANDANTE        4.0       22.0
# 6188              2               0   MANDANTE        7.0       20.0
# 6189              2               1   MANDANTE       20.0       12.0
# 6190              6               4   MANDANTE       10.0       21.0
# 6191              1               2  VISITANTE       20.0        5.0
# 6192              3               3     EMPATE       14.0       24.0
# 6193              3               0   MANDANTE        1.0       13.0
# 6194              1               2  VISITANTE       17.0        6.0
# 6195              1               0   MANDANTE        7.0       18.0
# 6196              3               2   MANDANTE        4.0        9.0
# 6197              2               4  VISITANTE       22.0        3.0
# 6198              3               1   MANDANTE       12.0       11.0
# 6199              0               0     EMPATE        2.0       15.0
# 6200              0               1  VISITANTE       19.0        8.0
# 6201              1               1     EMPATE       23.0       16.0
# 6202              0               3  VISITANTE       24.0        1.0
# 6203              2               2     EMPATE       11.0        7.0
# 6204              2               0   MANDANTE        3.0       22.0
# 6205              2               2     EMPATE       10.0        8.0
# 6206              1               1     EMPATE       17.0       14.0
# 6207              0               0     EMPATE       20.0       19.0
# 6208              2               2     EMPATE       12.0        5.0
# 6209              1               1     EMPATE       16.0       13.0
# 6210              2               2     EMPATE        9.0        6.0
# 6211              1               1     EMPATE       18.0       15.0
# 6212              2               0   MANDANTE        4.0       23.0
# 6213              4               2   MANDANTE        2.0       21.0
#
#       aproveitamento_5r_v  aproveitamento_5r_m  aproveitamento_10r_v  \
# 0                    0.67                 0.20                  0.67
# 1                    0.80                 0.13                  0.62
# 2                    0.27                 0.27                  0.29
# 3                    0.60                 0.27                  0.48
# 4                    0.53                 0.67                  0.52
# 5                    0.47                 0.20                  0.33
# 6                    0.73                 0.40                  0.62
# 7                    0.27                 0.47                  0.38
# 8                    0.47                 0.47                  0.43
# 9                    0.67                 0.47                  0.67
# 10                   0.20                 0.13                  0.17
# 11                   0.47                 0.33                  0.39
# 12                   0.33                 0.67                  0.44
# 13                   0.47                 0.67                  0.56
# 14                   0.67                 0.53                  0.72
# 15                   0.13                 0.33                  0.17
# 16                   0.47                 0.60                  0.44
# 17                   0.67                 0.67                  0.72
# 18                   0.20                 0.27                  0.17
# 19                   0.33                 0.47                  0.28
# 20                   0.67                 0.87                  0.67
# 21                   0.53                 0.67                  0.53
# 22                   0.40                 0.67                  0.40
# 23                   0.13                 0.13                  0.13
# 24                   0.33                 0.33                  0.33
# 25                   0.40                 0.47                  0.40
# 26                   0.53                 0.13                  0.53
# 27                   0.47                 0.20                  0.47
# 28                   0.47                 0.47                  0.47
# 29                   0.40                 0.20                  0.40
# ...                   ...                  ...                   ...
# 6184                 1.00                 1.00                  1.00
# 6185                 0.00                 0.33                  0.00
# 6186                 0.33                 0.00                  0.33
# 6187                 0.00                 1.00                  0.00
# 6188                 0.33                 0.33                  0.33
# 6189                 0.67                 0.00                  0.67
# 6190                 0.00                 0.00                  0.00
# 6191                 0.00                 0.00                  0.00
# 6192                 0.00                 0.00                  0.00
# 6193                 0.00                 0.00                  0.00
# 6194                 0.00                 0.00                  0.00
# 6195                 0.00                 0.00                  0.00
# 6196                 0.00                 0.00                  0.00
# 6197                 0.00                 0.00                  0.00
# 6198                 0.00                 0.00                  0.00
# 6199                 0.00                 0.00                  0.00
# 6200                 0.00                 0.00                  0.00
# 6201                 0.00                 0.00                  0.00
# 6202                 0.00                 0.00                  0.00
# 6203                 0.00                 0.00                  0.00
# 6204                 0.00                 0.00                  0.00
# 6205                 0.00                 0.00                  0.00
# 6206                 0.00                 0.00                  0.00
# 6207                 0.00                 0.00                  0.00
# 6208                 0.00                 0.00                  0.00
# 6209                 0.00                 0.00                  0.00
# 6210                 0.00                 0.00                  0.00
# 6211                 0.00                 0.00                  0.00
# 6212                 0.00                 0.00                  0.00
# 6213                 0.00                 0.00                  0.00
#
#       aproveitamento_10r_m
# 0                     0.14
# 1                     0.14
# 2                     0.33
# 3                     0.38
# 4                     0.76
# 5                     0.14
# 6                     0.48
# 7                     0.38
# 8                     0.62
# 9                     0.38
# 10                    0.17
# 11                    0.44
# 12                    0.72
# 13                    0.56
# 14                    0.50
# 15                    0.33
# 16                    0.56
# 17                    0.61
# 18                    0.28
# 19                    0.39
# 20                    0.87
# 21                    0.67
# 22                    0.67
# 23                    0.13
# 24                    0.33
# 25                    0.47
# 26                    0.13
# 27                    0.20
# 28                    0.47
# 29                    0.20
# ...                    ...
# 6184                  1.00
# 6185                  0.33
# 6186                  0.00
# 6187                  1.00
# 6188                  0.33
# 6189                  0.00
# 6190                  0.00
# 6191                  0.00
# 6192                  0.00
# 6193                  0.00
# 6194                  0.00
# 6195                  0.00
# 6196                  0.00
# 6197                  0.00
# 6198                  0.00
# 6199                  0.00
# 6200                  0.00
# 6201                  0.00
# 6202                  0.00
# 6203                  0.00
# 6204                  0.00
# 6205                  0.00
# 6206                  0.00
# 6207                  0.00
# 6208                  0.00
# 6209                  0.00
# 6210                  0.00
# 6211                  0.00
# 6212                  0.00
# 6213                  0.00
#
# [6214 rows x 16 columns]

# %%
rod
# Out:
# 9

# %%
ano
# Out:
# 2018

# %%
rodada_DF["posicao_m"] = rodada_DF.apply(lambda row: getPosicao(jogos, ano, rod, row["mandante"]),axis=1)

# %%
del rodada["placar"]

# %%
rodada_DF.head(10)
# Out:
#    mandante  visitante  placar   ano  rodada  posicao_m
# 0        57         51     NaN  2018      10        4.0
# 1        61         43     NaN  2018      10       12.0
# 2        59         56     NaN  2018      10       17.0
# 3        53         47     NaN  2018      10        7.0
# 4        58         52     NaN  2018      10        5.0
# 5        54         49     NaN  2018      10        2.0
# 6        55         48     NaN  2018      10        3.0
# 7        60         46     NaN  2018      10        8.0
# 8        42         45     NaN  2018      10       19.0
# 9        44         50     NaN  2018      10       10.0

# %%
rodada_DF["posicao_v"] = rodada_DF.apply(lambda row: getPosicao(jogos, ano, rod, row["visitante"]),axis=1)

# %%
rodada_DF["aproveitamento_10r_m"] = rodada_DF.apply(lambda row: getAproveitamento(jogos, ano, rod, row["mandante"]),axis=1)

# %%
rodada_DF["aproveitamento_10r_v"] = rodada_DF.apply(lambda row: getAproveitamento(jogos, ano, rod, row["visitante"]),axis=1)

# %%
rodada_DF
# Out:
#    mandante  visitante  placar   ano  rodada  posicao_m  posicao_v  \
# 0        57         51     NaN  2018      10        4.0       11.0
# 1        61         43     NaN  2018      10       12.0       20.0
# 2        59         56     NaN  2018      10       17.0       14.0
# 3        53         47     NaN  2018      10        7.0       15.0
# 4        58         52     NaN  2018      10        5.0       16.0
# 5        54         49     NaN  2018      10        2.0       13.0
# 6        55         48     NaN  2018      10        3.0        6.0
# 7        60         46     NaN  2018      10        8.0        1.0
# 8        42         45     NaN  2018      10       19.0       18.0
# 9        44         50     NaN  2018      10       10.0        9.0
#
#    aproveitamento_10r_m  aproveitamento_10r_v
# 0                  0.62                  0.38
# 1                  0.38                  0.14
# 2                  0.33                  0.43
# 3                  0.52                  0.14
# 4                  0.67                  0.29
# 5                  0.62                  0.38
# 6                  0.48                  0.48
# 7                  0.67                  0.76
# 8                  0.14                  0.38
# 9                  0.33                  0.62

# %%
rodada["prediction_RFC"] = rf_model.predict(rodada_DF[["ano", "rodada", "mandante", "visitante", "posicao_m", "posicao_v", "aproveitamento_10r_m", "aproveitamento_10r_v"]].values)

# %%
rodada["prediction_ABC"] = abc_model.predict(rodada_DF[["ano", "rodada", "mandante", "visitante", "posicao_m", "posicao_v", "aproveitamento_10r_m", "aproveitamento_10r_v"]].values)

# %%
rodada
# Out:
#        mandante      visitante prediction_RFC prediction_ABC
# 0     São Paulo  Internacional       MANDANTE       MANDANTE
# 1      Botafogo          Ceará       MANDANTE       MANDANTE
# 2       Vitória    Chapecoense      VISITANTE      VISITANTE
# 3   Corinthians         Santos       MANDANTE       MANDANTE
# 4  Sport Recife    Atlético-PR       MANDANTE       MANDANTE
# 5      Cruzeiro          Vasco       MANDANTE       MANDANTE
# 6        Grêmio      Palmeiras       MANDANTE       MANDANTE
# 7    Fluminense       Flamengo      VISITANTE      VISITANTE
# 8        Paraná          Bahia         EMPATE      VISITANTE
# 9    América-MG    Atlético-MG      VISITANTE      VISITANTE

# %%
rodada.to_csv(path_or_buf="data/prediction.10.csv",sep=";")
