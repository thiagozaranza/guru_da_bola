# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
jogos = pd.read_csv("data/jogos-resultado-posicao.csv",sep=",")

# %%
jogos.head()
# Out:
#    Unnamed: 0    campeonato   ano  rodada   data     mandante     visitante  \
# 0           0  brasileiro-a  2017      30  23-10     Botafogo   Corinthians
# 1           1  brasileiro-a  2017      30  22-10  Chapecoense    Fluminense
# 2           2  brasileiro-a  2017      30  22-10  Ponte Preta          Avaí
# 3           3  brasileiro-a  2017      30  22-10  Atlético-PR  Sport Recife
# 4           4  brasileiro-a  2017      30  22-10        Bahia       Vitória
#
#    gols_mandante  gols_visitante  resultado  posicao_m  posicao_v  \
# 0              2               1   MANDANTE        6.0        1.0
# 1              2               0   MANDANTE       11.0       13.0
# 2              1               2  VISITANTE       18.0       16.0
# 3              2               1   MANDANTE        9.0       15.0
# 4              2               1   MANDANTE       12.0       17.0
#
#    aproveitamento_5r_v  aproveitamento_5r_m  aproveitamento_10r_v  \
# ...
